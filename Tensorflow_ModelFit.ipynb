# %% [markdown]
# <a href="https://colab.research.google.com/github/FuadKhalit/MSc.DataScience/blob/master/Tensorflow_ModelFit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
model = tf.keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0,  0.0, 1.0, 2.0, 3.0, 4.0], dtype=float)
ys = np.array([-3.0, -1.0, 1.0, 3.0, 5.0, 7.0], dtype=float)

# %%
model.fit(xs,ys, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 39.6999
# Epoch 2/500
# 1/1 [==============================] - 0s 998us/step - loss: 31.5877
# Epoch 3/500
# 1/1 [==============================] - 0s 1ms/step - loss: 25.1981
# Epoch 4/500
# 1/1 [==============================] - 0s 2ms/step - loss: 20.1640
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 16.1964
# Epoch 6/500
# 1/1 [==============================] - 0s 1ms/step - loss: 13.0681
# Epoch 7/500
# 1/1 [==============================] - 0s 2ms/step - loss: 10.6002
# Epoch 8/500
# 1/1 [==============================] - 0s 1ms/step - loss: 8.6520
# Epoch 9/500
# 1/1 [==============================] - 0s 5ms/step - loss: 7.1128
# Epoch 10/500
# 1/1 [==============================] - 0s 2ms/step - loss: 5.8956
# Epoch 11/500
# 1/1 [==============================] - 0s 2ms/step - loss: 4.9318
# Epoch 12/500
# 1/1 [==============================] - 0s 1ms/step - loss: 4.1675
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.977716]]
